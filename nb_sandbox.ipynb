# %%
import pandas as pd
from preprocessing import ReleaseReader

cr_dict = ReleaseReader('data/champions.csv').to_dict()
list(cr_dict.items())[:5]
# Out:
# /usr/local/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# [('Aatrox', Timestamp('2013-06-13 00:00:00')),
#  ('Ahri', Timestamp('2011-12-14 00:00:00')),
#  ('Akali', Timestamp('2010-05-11 00:00:00')),
#  ('Akshan', Timestamp('2021-07-22 00:00:00')),
#  ('Alistar', Timestamp('2009-02-21 00:00:00'))]

# %%
from preprocessing import PatchHistoryReader

ph_df = PatchHistoryReader('data/patches.jsonl').to_df()
ph_df
# Out:
#               patch       date  champion                about  \
# 0             V12.5 2022-03-02      Ahri             Fox-Fire
# 1             V12.5 2022-03-02      Ahri             Fox-Fire
# 2             V12.5 2022-03-02      Ahri                Charm
# 3             V12.5 2022-03-02   Caitlyn  Piltover Peacemaker
# 4             V12.5 2022-03-02     Elise              General
# ...             ...        ...       ...                  ...
# 22622  Alpha Week 2        NaT     Teemo                 None
# 22623  Alpha Week 2        NaT  Tristana                 None
# 22624  Alpha Week 2        NaT   Warwick                 None
# 22625  Alpha Week 2        NaT   Warwick                 None
# 22626  Alpha Week 2        NaT   Warwick                 None
#
#                                                     text
# 0                     Mana cost increased to 30 from 25.
# 1      Base damage reduced to 50 / 75 / 100 / 125 / 1...
# ...

# %%
releases = ph_df['champion'].map(lambda c: cr_dict[c])
on_release_df = ph_df[ph_df['date'] <= releases]
on_release_df
# Out:
#                      patch       date      champion                  about  \
# 103                  V12.4 2022-02-16  Renata Glasc      Leverage (Innate)
# 104                  V12.4 2022-02-16  Renata Glasc      Leverage (Innate)
# 105                  V12.4 2022-02-16  Renata Glasc      Leverage (Innate)
# 106                  V12.4 2022-02-16  Renata Glasc          Handshake (Q)
# 107                  V12.4 2022-02-16  Renata Glasc          Handshake (Q)
# ...                    ...        ...           ...                    ...
# 22101  June 12, 2009 Patch 2009-06-12       Karthus  Death Defied (Innate)
# 22102  June 12, 2009 Patch 2009-06-12       Karthus          Lay Waste (Q)
# 22103  June 12, 2009 Patch 2009-06-12       Karthus       Wall of Pain (W)
# 22104  June 12, 2009 Patch 2009-06-12       Karthus             Defile (E)
# 22105  June 12, 2009 Patch 2009-06-12       Karthus  Fallen One (Ultimate)
#
#                                                     text
# ...

# %%
on_release_df2 = ph_df[ph_df['about'].str.contains(r"\(.*\)").fillna(False)]
on_release_df2
# Out:
#                    patch       date      champion  \
# 103                V12.4 2022-02-16  Renata Glasc
# 104                V12.4 2022-02-16  Renata Glasc
# 105                V12.4 2022-02-16  Renata Glasc
# 106                V12.4 2022-02-16  Renata Glasc
# 107                V12.4 2022-02-16  Renata Glasc
# ...                  ...        ...           ...
# 22267  May 9, 2009 Patch 2009-05-09  Twisted Fate
# 22268  May 9, 2009 Patch 2009-05-09  Twisted Fate
# 22269  May 9, 2009 Patch 2009-05-09  Twisted Fate
# 22270  May 9, 2009 Patch 2009-05-09  Twisted Fate
# 22321  May 1, 2009 Patch 2009-05-01      Tristana
#
#                               about  \
# 103               Leverage (Innate)
# 104               Leverage (Innate)
# 105               Leverage (Innate)
# 106                   Handshake (Q)
# 107                   Handshake (Q)
# ...                             ...
# 22267               Pick a Card (W)
# 22268               Pick a Card (W)
# ...

# %%
others = sorted(set(on_release_df2.index) - set(on_release_df.index))
ph_df.iloc[others][100:120]
# Out:
#       patch       date      champion                    about  \
# 3657  V10.7 2020-04-01  Fiddlesticks    Bountiful Harvest (W)
# 3658  V10.7 2020-04-01  Fiddlesticks    Bountiful Harvest (W)
# 3659  V10.7 2020-04-01  Fiddlesticks    Bountiful Harvest (W)
# 3660  V10.7 2020-04-01  Fiddlesticks    Bountiful Harvest (W)
# 3661  V10.7 2020-04-01  Fiddlesticks    Bountiful Harvest (W)
# 3662  V10.7 2020-04-01  Fiddlesticks    Bountiful Harvest (W)
# 3663  V10.7 2020-04-01  Fiddlesticks    Bountiful Harvest (W)
# 3664  V10.7 2020-04-01  Fiddlesticks    Bountiful Harvest (W)
# 3665  V10.7 2020-04-01  Fiddlesticks                 Reap (E)
# 3666  V10.7 2020-04-01  Fiddlesticks                 Reap (E)
# 3667  V10.7 2020-04-01  Fiddlesticks                 Reap (E)
# 3668  V10.7 2020-04-01  Fiddlesticks                 Reap (E)
# 3669  V10.7 2020-04-01  Fiddlesticks                 Reap (E)
# 3670  V10.7 2020-04-01  Fiddlesticks            Crowstorm (R)
# ...
